# %% [markdown]
# ## PlaceHolder를 이용한 Linear regression Example

# %%
import tensorflow as tf

#x_train = [1, 2, 3]
x = tf.placeholder(tf.float32, shape=[None])

#y_train = [1, 2, 3]
y = tf.placeholder(tf.float32, shape=[None])


W = tf.Variable(tf.random_normal([1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias")

hypothesis = x * W + b
cost = tf.reduce_mean(tf.square(hypothesis - y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, W_val, b_val,_ = sess.run([cost, W, b, train], feed_dict={x:[1,2,3], y:[1,2,3]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 30.363218 [-1.2360001] [-0.07601443]
# 20 0.35024643 [0.5001413] [0.6450629]
# 40 0.07124793 [0.678941] [0.68306774]
# 60 0.062470373 [0.7088179] [0.6574715]
# 80 0.056716334 [0.7239105] [0.6271922]
# 100 0.051510464 [0.73701984] [0.59777546]
# 120 0.046782617 [0.7493916] [0.56968784]
# 140 0.042488758 [0.76117057] [0.5429151]
# 160 0.038588975 [0.7723947] [0.51740015]
# 180 0.03504714 [0.7830913] [0.49308434]
# 200 0.031830367 [0.7932852] [0.46991122]
# 220 0.02890887 [0.80300003] [0.44782716]
# 240 0.026255487 [0.8122583] [0.42678097]
# 260 0.023845648 [0.82108146] [0.4067238]
# 280 0.021657022 [0.82948995] [0.38760936]
# 300 0.019669246 [0.83750325] [0.3693932]
# 320 0.017863931 [0.84514004] [0.35203302]
# 340 0.01622429 [0.8524179] [0.33548877]
# 360 0.014735176 [0.8593538] [0.31972206]
# 380 0.013382723 [0.8659636] [0.30469626]
# 400 0.012154375 [0.87226284] [0.29037663]
# 420 0.011038821 [0.878266] [0.27673]
# 440 0.010025634 [0.883987] [0.26372468]
# 460 0.0091054365 [0.8894393] [0.25133058]
# 480 0.0082697 [0.89463526] [0.23951894]
# 500 0.0075106644 [0.899587] [0.22826242]
# 520 0.0068213195 [0.904306] [0.21753496]
# 540 0.006195231 [0.90880334] [0.20731162]
# 560 0.005626606 [0.9130893] [0.19756867]
# 580 0.0051101544 [0.91717374] [0.18828362]
# 600 0.004641133 [0.9210663] [0.17943498]
# 620 0.004215154 [0.92477584] [0.17100221]
# 640 0.0038282638 [0.92831105] [0.1629657]
# 660 0.0034769047 [0.9316802] [0.15530695]
# 680 0.0031577738 [0.934891] [0.14800811]
# 700 0.002867936 [0.93795085] [0.14105226]
# 720 0.0026046997 [0.940867] [0.13442329]
# 740 0.0023656355 [0.94364595] [0.12810588]
# 760 0.002148514 [0.9462944] [0.12208538]
# 780 0.0019513117 [0.94881827] [0.11634784]
# 800 0.0017722062 [0.95122373] [0.11087991]
# 820 0.0016095483 [0.953516] [0.105669]
# 840 0.0014618194 [0.9557006] [0.10070297]
# 860 0.0013276482 [0.9577825] [0.0959703]
# 880 0.001205794 [0.9597665] [0.09146012]
# 900 0.0010951255 [0.96165735] [0.08716182]
# 920 0.0009946052 [0.9634593] [0.08306555]
# 940 0.00090331654 [0.96517664] [0.07916175]
# 960 0.00082040863 [0.9668132] [0.07544143]
# 980 0.0007451048 [0.9683729] [0.07189595]
# 1000 0.0006767232 [0.9698592] [0.06851716]
# 1020 0.0006146049 [0.9712757] [0.06529709]
# 1040 0.0005581944 [0.9726257] [0.06222836]
# 1060 0.0005069604 [0.9739122] [0.05930384]
# 1080 0.0004604289 [0.97513825] [0.05651674]
# 1100 0.00041817199 [0.97630656] [0.05386065]
# 1120 0.00037978837 [0.9774201] [0.05132942]
# 1140 0.000344932 [0.9784812] [0.04891716]
# 1160 0.00031327413 [0.9794924] [0.04661829]
# 1180 0.00028452007 [0.9804563] [0.04442747]
# 1200 0.00025840546 [0.98137474] [0.04233955]
# 1220 0.00023468857 [0.9822501] [0.04034974]
# 1240 0.00021314819 [0.98308426] [0.03845345]
# 1260 0.00019358518 [0.9838792] [0.03664629]
# 1280 0.00017581618 [0.98463684] [0.03492407]
# 1300 0.0001596799 [0.9853589] [0.03328274]
# 1320 0.00014502417 [0.9860469] [0.03171858]
# 1340 0.00013171101 [0.9867027] [0.03022795]
# 1360 0.00011962215 [0.98732764] [0.02880735]
# 1380 0.00010864422 [0.98792315] [0.0274535]
# 1400 9.8672346e-05 [0.9884907] [0.0261633]
# 1420 8.9615234e-05 [0.98903155] [0.02493375]
# 1440 8.139154e-05 [0.98954713] [0.02376201]
# 1460 7.392074e-05 [0.99003845] [0.02264524]
# 1480 6.713547e-05 [0.9905066] [0.0215809]
# 1500 6.0972903e-05 [0.99095273] [0.02056666]
# 1520 5.5376804e-05 [0.9913779] [0.01960009]
# 1540 5.0293515e-05 [0.9917831] [0.01867895]
# 1560 4.567789e-05 [0.99216926] [0.01780111]
# 1580 4.1485004e-05 [0.9925373] [0.0169645]
# 1600 3.7677e-05 [0.992888] [0.01616724]
# 1620 3.4219494e-05 [0.9932222] [0.01540748]
# 1640 3.10793e-05 [0.99354076] [0.0146834]
# 1660 2.8225768e-05 [0.99384433] [0.01399332]
# 1680 2.5635074e-05 [0.9941336] [0.01333568]
# 1700 2.328183e-05 [0.9944093] [0.01270896]
# 1720 2.1145393e-05 [0.994672] [0.01211169]
# 1740 1.920506e-05 [0.99492234] [0.01154254]
# 1760 1.7442317e-05 [0.99516106] [0.01100013]
# 1780 1.5841282e-05 [0.9953884] [0.01048317]
# 1800 1.4387574e-05 [0.9956052] [0.00999051]
# 1820 1.3067267e-05 [0.9958117] [0.00952099]
# 1840 1.1867264e-05 [0.9960085] [0.00907354]
# 1860 1.07783235e-05 [0.99619615] [0.00864712]
# 1880 9.789036e-06 [0.9963749] [0.00824074]
# 1900 8.890402e-06 [0.9965452] [0.00785348]
# 1920 8.074566e-06 [0.99670756] [0.00748444]
# 1940 7.3335773e-06 [0.9968623] [0.0071327]
# 1960 6.660653e-06 [0.99700975] [0.00679749]
# 1980 6.0492166e-06 [0.99715024] [0.00647805]
# 2000 5.4941297e-06 [0.9972842] [0.00617364]

# %%
print(sess.run(hypothesis, feed_dict={x:[5]}))
# Out:
# [4.9925942]

# %%
print(sess.run(hypothesis, feed_dict={x:[2.5]}))
# Out:
# [2.499384]

# %%
print(sess.run(hypothesis, feed_dict={x:[1.5, 5.5]}))
# Out:
# [1.5020999 5.4912367]
